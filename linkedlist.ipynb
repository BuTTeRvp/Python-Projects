# %%
class LL:
    def __init__(self, data):
        self.data = data
        self.pointer = None                                               
        
    
    def insert(self, new_name):
        x = LL(new_name)
        while self.pointer:
            self = self.pointer
        self.pointer = x

    def __str__(self,):
        return "%s,%s" %(self.data, self.pointer)

    def print_list(self):
        x = self
        while x:
            print(x.data, end=" ")
            x = x.pointer
        

    def search(self,search_data):
        x = self
        while x:
            if x.data == search_data:
                print("Found")
                return
            x = x.pointer
        print("Not FOund")
                
    # #case 1 delete 1st element
    # def del_start(self, del_name):
    #     if self.data == del_name:
    #         self.data = self.pointer.data
    #         self.pointer = self.pointer.pointer
    # #case 2 delete mid element  
    # def del_mid(self,del_name):
    #     while self:
    #         if self.pointer.data == del_name:
    #             self.pointer = self.pointer.pointer
    #             return 
    #         self = self.pointer
    # #case 3 last element
    # def del_last(self, del_name):
    #     while self:
    #         if self.pointer.data == del_name:
    #             self.pointer = self.pointer.pointer
    #             return
    #         self = self.pointer
        
    #concatenate case 1 2 and 3

    def delete(self, del_name):
        if self.data == del_name:
            self.data = self.pointer.data
            self.pointer = self.pointer.pointer
        else:
            try:
                while self:
                    if self.pointer.data == del_name:
                        self.pointer = self.pointer.pointer
                        return 
                    self = self.pointer
            except AttributeError as attri_error:
                print("Not in List")
